# %%
import cv2, numpy as np, matplotlib.pyplot as plt, matplotlib.image as img_

# %%
path=r"D:\Asus\Documents\blurred-numbers-vector-3182052.jpg"

# %%
img= img_.imread(path)

# %%
img
# Out:
# array([[[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        ...,
#
#        [[ 17,  18,  36],
#         [ 17,  18,  36],
#         [ 17,  18,  36],
#         ...,
#         [ 17,  18,  36],
#         [ 17,  18,  36],
#         [ 17,  18,  36]],
#
#        [[ 17,  18,  36],
#         [ 17,  18,  36],
#         [ 17,  18,  36],
#         ...,
#         [ 17,  18,  36],
#         [ 17,  18,  36],
#         [ 17,  18,  36]],
#
#        [[ 17,  18,  36],
#         [ 17,  18,  36],
#         [ 17,  18,  36],
#         ...,
#         [ 17,  18,  36],
#         [ 17,  18,  36],
#         [ 17,  18,  36]]], dtype=uint8)

# %%
plt.imshow(img)

# %%
src_pts=np.float32([[10,20],[250,20],[250,240],[20,240]])

# %%
width=img.shape[0]
height=img.shape[1]

# %%
destination=np.float32([[0,0],[width,0],[width,height],[0,height]])

# %%
matrix= cv2.getPerspectiveTransform(src_pts, destination)

# %%
img1= cv2.warpPerspective(img,matrix, (width, height))

# %%
plt.imshow(img1)

# %%
mat_=np.ones((8,8))

# %%
plt.imshow(cv2.erode(img,mat_, iterations=1))

# %%
plt.imshow(cv2.erode(img,mat_, iterations=2))

# %%
plt.imshow(cv2.dilate(img,mat_, iterations=1))

# %%
plt.imshow(cv2.dilate(img,mat_, iterations=2))

# %%
cropped=img[0:250,20:250,:]

# %%
plt.imshow(cropped)

# %%
sharpening=np.array([[0,-1,0],[-1,
                               6,-1],[0,-1,0]])

# %%
plt.imshow(cv2.filter2D(img,-1,sharpening))

# %%
plt.imshow(cv2.filter2D(cropped,-1,sharpening))

# %% [markdown]
# plt.imshow(cv2.filter2D(cropped,-1,sharpening))
